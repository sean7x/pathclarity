# %%
import pandas as pd
import os
import json

# %% [markdown]
# ### 1 - Load the training data

# %%
file_path = os.path.join('..', 'data', 'cleaned')

train_df = pd.read_csv(os.path.join(file_path, 'train.csv'))
train_df.head()
# Out:
# /var/folders/df/mzw6vbrs5h5gsxlb90rrfgsm0000gn/T/ipykernel_2338/1944286187.py:3: DtypeWarning: Columns (104,105,107,108,113,114,115,116,155) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv(os.path.join(file_path, 'train.csv'))
#           file    VMONTH   VYEAR      VDAYR    YEAR   AGE     SEX  \
# 0  opd2006.csv  December  2006.0     Friday  2006.0  55.0    Male
# 1  opd2006.csv  November  2006.0   Thursday  2006.0  66.0    Male
# 2  opd2006.csv  November  2006.0  Wednesday  2006.0  71.0  Female
# 3  opd2006.csv  November  2006.0    Tuesday  2006.0   1.0  Female
# 4  opd2006.csv  November  2006.0     Monday  2006.0  21.0  Female
#
#                    ETHNIC        RACE     USETOBAC  ... PHYSASST NPNMW RNLPN  \
# 0  Not Hispanic or Latino  White Only  Not current  ...       No    No    No
# 1  Not Hispanic or Latino  White Only  Not current  ...       No    No    No
# 2  Not Hispanic or Latino  White Only  Not current  ...       No    No    No
# 3  Not Hispanic or Latino  White Only  Not current  ...       No    No    No
# 4  Not Hispanic or Latino  White Only      Current  ...       No    No    No
#
#   OTHPROV  MHP                           NODISP REFOTHMD RETAPPT OTHDISP  \
# 0      No  NaN  One or more dispositions marked       No      No      No
# 1      No  NaN  One or more dispositions marked       No      No      No
# 2      No  NaN  One or more dispositions marked      Yes      No      No
# 3      No  NaN  One or more dispositions marked       No      No      No
# 4      No  NaN  One or more dispositions marked       No      No      No
#
#   ERADMHOS
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#
# [5 rows x 161 columns]

# %%
# Load the variables dictionary
with open(os.path.join(file_path, 'variables.json'), 'r') as f:
    variables = json.load(f)

variables
# Out:
# {'dateOfVisit': ['VMONTH', 'VYEAR', 'VDAYR', 'YEAR'],
#  'demographics': ['AGE', 'SEX', 'ETHNIC', 'RACE', 'USETOBAC'],
#  'payment': ['PAYPRIV',
#   'PAYMCARE',
#   'PAYMCAID',
#   'PAYWKCMP',
#   'PAYSELF',
#   'PAYNOCHG',
#   'PAYOTH',
#   'PAYDK',
#   'PAYTYPER'],
#  'visitReason': ['INJDET', 'INJURY', 'MAJOR', 'RFV1', 'RFV2', 'RFV3'],
#  'patientClinicHistory': ['SENBEFOR', 'PASTVIS'],
#  'vitalSigns': ['HTIN', 'WTLB', 'BMI', 'TEMPF', 'BPSYS', 'BPDIAS'],
#  'imputedFields': ['BDATEFL', 'SEXFL', 'SENBEFL', 'PASTFL'],
#  'physicianDiagnoses': ['DIAG1', 'DIAG2', 'DIAG3'],
#  'differentialDiagnoses': ['PRDIAG1', 'PRDIAG2', 'PRDIAG3'],
#  'presentSymptomsStatus': ['ARTHRTIS',
#   'ASTHMA',
#   'CANCER',
#   'CASTAGE',
#   'CEBVD',
#   'CHF',
#   'CRF',
#   'COPD',
#   'DEPRN',
#   'DIABETES',
#   'HYPLIPID',
#   'HTN',
#   'IHD',
#   'OBESITY',
#   'OSTPRSIS',
#   'NOCHRON',
#   'TOTCHRON',
#   'DMP'],
#  'services': ['BREAST',
#   'PELVIC',
#   'RECTAL',
#   'SKIN',
#   'DEPRESS',
#   'BONEDENS',
#   'MAMMO',
#   'MRI',
#   'ULTRASND',
#   'XRAY',
#   'OTHIMAGE',
#   'CBC',
#   'ELECTROL',
#   'GLUCOSE',
#   'HGBA',
#   'CHOLEST',
#   'PSA',
#   'OTHERBLD',
#   'BIOPSY',
#   'CHLAMYD',
#   'PAPCONV',
#   'PAPLIQ',
#   'PAPUNSP',
#   'HPVDNA',
#   'EKG',
#   'SPIRO',
#   'URINE',
#   'HTTAKE',
#   'WTTAKE',
#   'TEMPTAKE',
#   'BLODPRES',
#   'CAM',
#   'DME',
#   'HOMEHLTH',
#   'HOSPICE',
#   'PT',
#   'RADTHER',
#   'SPOCTHER',
#   'PSYCHOTH',
#   'OTHMNTL',
#   'EXCISION',
#   'ORTHO',
#   'WOUND',
#   'ECHOCARD',
#   'OTHULTRA',
#   'PROC1',
#   'PROC2',
#   'PROC3',
#   'PROC4',
#   'PROC5',
#   'PROC6',
#   'PROC7',
#   'PROC8',
#   'PROC9',
#   'CATSCAN',
#   'PREGTEST',
#   'FOOT',
#   'RETINAL',
#   'HIVTEST',
#   'CAST',
#   'SPLINT'],
#  'healthEducation': ['ASTHMAED',
#   'DIETNUTR',
#   'EXERCISE',
#   'GRWTHDEV',
#   'INJPREV',
#   'STRESMGT',
#   'TOBACED',
#   'WTREDUC',
#   'OTHLTHED'],
#  'medicationsAndImmunizations': ['MED1',
#   'MED2',
#   'MED3',
#   'MED4',
#   'MED5',
#   'MED6',
#   'MED7',
#   'MED8',
#   'NCMED1',
#   'NCMED2',
#   'NCMED3',
#   'NCMED4',
#   'NCMED5',
#   'NCMED6',
#   'NCMED7',
#   'NCMED8',
#   'NUMNEW',
#   'NUMCONT'],
#  'providersSeen': ['NOPROVID',
#   'PHYS',
#   'PHYSASST',
#   'NPNMW',
#   'RNLPN',
#   'OTHPROV',
#   'MHP'],
#  'visitDisposition': ['NODISP', 'REFOTHMD', 'RETAPPT', 'OTHDISP', 'ERADMHOS']}
